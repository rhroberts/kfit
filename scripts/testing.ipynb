# %%
from kfit import models, tools

f = tools.get_data_source()
tools.to_csv(f)
# Out:
#                            0                   1                   2  \
# 3
# III                 pressure                   I                  II
# 152.19298102386222       0.0  135.28267255922404  142.22570990147787
# 154.59135988511636       1.6  137.39136707457976  144.51051738830466
# 155.44019443749434       4.0  136.43175079450705  145.12985115126207
# 159.42837151755566      7.25   138.9063291823072  147.42731116776238
# 162.15929046064863      10.0  139.22442755690312   149.3972071515545
# 163.49238887697462      11.3   139.4181992402517  149.91299351155786
#
#                                      4                   5  \
# 3
# III                                 IV                   V
# 152.19298102386222  162.27680605655235  213.73661713008048
# 154.59135988511636   163.9988629441189   217.6507292404957
# 155.44019443749434  164.67177660586248   220.0966003872353
# 159.42837151755566  167.28230631710804   225.6897663874879
# ...

# %%
import pandas as pd
pd.read_csv()
